# %% [markdown]
# # 04 Backtest Report
#
# Inspect model comparison backtest metrics. Backtesting is implemented in `src/backtest/`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
bt = pd.read_csv(ROOT / 'reports' / 'tables' / 'model_comparison_metrics.csv')
bt
