# %% [markdown]
# # 01 Data Check
#
# Quick inspection notebook for the AKShare daily panel. Core logic lives in `src/` and `scripts/`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sample_path = ROOT / 'data' / 'sample' / 'a_share_akshare_daily.parquet'
df = pd.read_parquet(sample_path)
df.head(), df.shape, df['code'].nunique(), (df['date'].min(), df['date'].max())
