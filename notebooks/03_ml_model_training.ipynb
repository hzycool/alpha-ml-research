# %% [markdown]
# # 03 ML Model Training
#
# Inspect out-of-sample prediction metrics. Training is executed by `scripts/run_04_train_ml_models.py` and `scripts/run_05_train_mlp.py`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
metrics = pd.read_csv(ROOT / 'reports' / 'tables' / 'prediction_metrics_all.csv')
metrics
