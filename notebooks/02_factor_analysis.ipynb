# %% [markdown]
# # 02 Factor Analysis
#
# Inspect IC/RankIC summary generated by `scripts/run_03_factor_analysis.py`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
summary = pd.read_csv(ROOT / 'reports' / 'tables' / 'factor_ic_summary.csv')
summary.head(10)
